# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    index        id                            title   type  \
# 0      0   tm84618                      Taxi Driver  MOVIE
# 1      1  tm127384  Monty Python and the Holy Grail  MOVIE
# 2      2   tm70993                    Life of Brian  MOVIE
# 3      3  tm190788                     The Exorcist  MOVIE
# 4      4   ts22164     Monty Python's Flying Circus   SHOW
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  King Arthur, accompanied by his squire, recrui...          1975
# 2  Brian Cohen is an average young Jewish man, bu...          1979
# 3  12-year-old Regan MacNeil begins to adapt an e...          1973
# 4  A British sketch comedy series with the shows ...          1969
#
#   age_certification  runtime    imdb_id  imdb_score  imdb_votes
# 0                 R      113  tt0075314         8.3    795222.0
# 1                PG       91  tt0071853         8.2    530877.0
# ...

# %%
movies.isnull().sum()
# Out:
# index                   0
# id                      0
# title                   0
# type                    0
# description             5
# release_year            0
# age_certification    2285
# runtime                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes             16
# dtype: int64

# %%
movies.shape
# Out:
# (5283, 11)

# %%
movies.dropna(subset=['description', 'imdb_votes'], inplace=True)

# %%
movies.shape
# Out:
# (5263, 11)

# %%
# Top movies for each year

# %%
top_movies_each_year = movies.loc[movies.groupby('release_year')['imdb_score'].idxmax()]
top_movies_each_year.set_index('release_year', inplace=True)

# %%
top_movies_each_year
# Out:
#               index        id                title   type  \
# release_year
# 1953             23  tm102287      Raya and Sakina  MOVIE
# 1954             14   tm16479      White Christmas  MOVIE
# 1956             21  tm204541          Dark Waters  MOVIE
# 1958             15  tm135083        Cairo Station  MOVIE
# 1959             36  tm358653                Ujala  MOVIE
# ...             ...       ...                  ...    ...
# 2018           2787  ts265844             #ABtalks   SHOW
# 2019           3144   ts85398           Our Planet   SHOW
# 2020           3026   ts81120       The Last Dance   SHOW
# 2021           4429  ts222333               Arcane   SHOW
# 2022           4628  ts296563  Who Rules The World   SHOW
#
#                                                     description  \
# release_year
# 1953          Dramatic rendition of a real life crime wave t...
# 1954          Two talented song-and-dance men team up after ...
# ...

# %%
top_movies_each_year = movies.loc[movies.groupby('release_year')['imdb_score'].idxmax()]

# %%
# plotting a graph

plt.figure(figsize=(12, 6))
plt.plot(top_movies_each_year['release_year'], top_movies_each_year['imdb_score'], marker='o')
plt.title('Top IMDb Rating Movies for Each Year')
plt.xlabel('Year')
plt.ylabel('IMDb Rating')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(top_movies_each_year['release_year'], top_movies_each_year['imdb_score'])
plt.title('Top IMDb Rating Movies for Each Year')
plt.xlabel('Year')
plt.ylabel('IMDb Rating')
plt.xticks(ticks=top_movies_each_year['release_year'],rotation=90)
# plt.grid(True)
plt.show()

# %%
movies.head()
# Out:
#    index        id                            title   type  \
# 0      0   tm84618                      Taxi Driver  MOVIE
# 1      1  tm127384  Monty Python and the Holy Grail  MOVIE
# 2      2   tm70993                    Life of Brian  MOVIE
# 3      3  tm190788                     The Exorcist  MOVIE
# 4      4   ts22164     Monty Python's Flying Circus   SHOW
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  King Arthur, accompanied by his squire, recrui...          1975
# 2  Brian Cohen is an average young Jewish man, bu...          1979
# 3  12-year-old Regan MacNeil begins to adapt an e...          1973
# 4  A British sketch comedy series with the shows ...          1969
#
#   age_certification  runtime    imdb_id  imdb_score  imdb_votes
# 0                 R      113  tt0075314         8.3    795222.0
# 1                PG       91  tt0071853         8.2    530877.0
# ...

# %%
movies
# Out:
#       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
# Sort the data by runtime
sorted_movies = movies.sort_values(by='runtime')
sorted_movies
# Out:
#       index        id                                     title   type  \
# 5282   5282  ts271048        Mighty Little Bheem: Kite Festival   SHOW
# 4961   4961  ts243780                                  Sharkdog   SHOW
# 2503   2503   ts74765                      Daughters of Destiny   SHOW
# 4161   4161   ts88146  Larry Charles' Dangerous World of Comedy   SHOW
# 5098   5098  ts257873                                 Dive Club   SHOW
# ...     ...       ...                                       ...    ...
# 428     428   tm29269                              Jodhaa Akbar  MOVIE
# 378     378   tm43399         Lagaan: Once Upon a Time in India  MOVIE
# 495     495   tm25842                       A Lion in the House  MOVIE
# 45       45  tm180542               Once Upon a Time in America  MOVIE
# 24       24   tm76557                            No Longer Kids  MOVIE
#
#                                             description  release_year  \
# ...

# %%
# Sort the data by release year
sorted_movies = movies.sort_values(by='release_year')
sorted_movies
# Out:
#       index         id                                 title   type  \
# 23       23   tm102287                       Raya and Sakina  MOVIE
# 27       27    tm19608                       The Blazing Sun  MOVIE
# 14       14    tm16479                       White Christmas  MOVIE
# 21       21   tm204541                           Dark Waters  MOVIE
# 15       15   tm135083                         Cairo Station  MOVIE
# ...     ...        ...                                   ...    ...
# 4755   4755  tm1120902                         The Privilege  MOVIE
# 4895   4895   tm949382                          Looop Lapeta  MOVIE
# 4757   4757  tm1144897                    My Father's Violin  MOVIE
# 4574   4574   ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 4817   4817  tm1137862                        Four to Dinner  MOVIE
#
#                                             description  release_year  \
# 23    Dramatic rendition of a real life crime wave t...          1953
# ...

# %%
movies.sort_values(by='release_movieyear', inplace= True)

# %%
movies
# Out:
#       index         id                                 title   type  \
# 23       23   tm102287                       Raya and Sakina  MOVIE
# 27       27    tm19608                       The Blazing Sun  MOVIE
# 14       14    tm16479                       White Christmas  MOVIE
# 21       21   tm204541                           Dark Waters  MOVIE
# 15       15   tm135083                         Cairo Station  MOVIE
# ...     ...        ...                                   ...    ...
# 4755   4755  tm1120902                         The Privilege  MOVIE
# 4895   4895   tm949382                          Looop Lapeta  MOVIE
# 4757   4757  tm1144897                    My Father's Violin  MOVIE
# 4574   4574   ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 4817   4817  tm1137862                        Four to Dinner  MOVIE
#
#                                             description  release_year  \
# 23    Dramatic rendition of a real life crime wave t...          1953
# ...

# %%
movies.reset_index(drop=True, inplace=True)

# %%
movies
# Out:
#       index         id                                 title   type  \
# 0        23   tm102287                       Raya and Sakina  MOVIE
# 1        27    tm19608                       The Blazing Sun  MOVIE
# 2        14    tm16479                       White Christmas  MOVIE
# 3        21   tm204541                           Dark Waters  MOVIE
# 4        15   tm135083                         Cairo Station  MOVIE
# ...     ...        ...                                   ...    ...
# 5258   4755  tm1120902                         The Privilege  MOVIE
# 5259   4895   tm949382                          Looop Lapeta  MOVIE
# 5260   4757  tm1144897                    My Father's Violin  MOVIE
# 5261   4574   ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 5262   4817  tm1137862                        Four to Dinner  MOVIE
#
#                                             description  release_year  \
# 0     Dramatic rendition of a real life crime wave t...          1953
# ...

# %%
movies.drop('index', axis=1, inplace=True)

# %%
movies
# Out:
#              id                                 title   type  \
# 0      tm102287                       Raya and Sakina  MOVIE
# 1       tm19608                       The Blazing Sun  MOVIE
# 2       tm16479                       White Christmas  MOVIE
# 3      tm204541                           Dark Waters  MOVIE
# 4      tm135083                         Cairo Station  MOVIE
# ...         ...                                   ...    ...
# 5258  tm1120902                         The Privilege  MOVIE
# 5259   tm949382                          Looop Lapeta  MOVIE
# 5260  tm1144897                    My Father's Violin  MOVIE
# 5261   ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 5262  tm1137862                        Four to Dinner  MOVIE
#
#                                             description  release_year  \
# 0     Dramatic rendition of a real life crime wave t...          1953
# 1     A rich landlord floods and destroys a village ...          1954
# ...

# %%
movies.rename_axis('index', inplace=True)

# %%
movies
# Out:
#        level_0  index         id                                 title   type  \
# index
# 0            0      0   tm102287                       Raya and Sakina  MOVIE
# 1            1      1    tm19608                       The Blazing Sun  MOVIE
# 2            2      2    tm16479                       White Christmas  MOVIE
# 3            3      3   tm204541                           Dark Waters  MOVIE
# 4            4      4   tm135083                         Cairo Station  MOVIE
# ...        ...    ...        ...                                   ...    ...
# 5258      5258   5258  tm1120902                         The Privilege  MOVIE
# 5259      5259   5259   tm949382                          Looop Lapeta  MOVIE
# 5260      5260   5260  tm1144897                    My Father's Violin  MOVIE
# 5261      5261   5261   ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 5262      5262   5262  tm1137862                        Four to Dinner  MOVIE
#
# ...

# %%
movies = movies.reset_index()

# %%
movies.drop('index', axis=1, inplace=True)

# %%
movies
# Out:
#        index         id                                 title   type  \
# index
# 0          0   tm102287                       Raya and Sakina  MOVIE
# 1          1    tm19608                       The Blazing Sun  MOVIE
# 2          2    tm16479                       White Christmas  MOVIE
# 3          3   tm204541                           Dark Waters  MOVIE
# 4          4   tm135083                         Cairo Station  MOVIE
# ...      ...        ...                                   ...    ...
# 5258    5258  tm1120902                         The Privilege  MOVIE
# 5259    5259   tm949382                          Looop Lapeta  MOVIE
# 5260    5260  tm1144897                    My Father's Violin  MOVIE
# 5261    5261   ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 5262    5262  tm1137862                        Four to Dinner  MOVIE
#
#                                              description  release_year  \
# index
# ...

# %%
movies.drop('index', axis=1, inplace=True)
movies
# Out:
#               id                                 title   type  \
# index
# 0       tm102287                       Raya and Sakina  MOVIE
# 1        tm19608                       The Blazing Sun  MOVIE
# 2        tm16479                       White Christmas  MOVIE
# 3       tm204541                           Dark Waters  MOVIE
# 4       tm135083                         Cairo Station  MOVIE
# ...          ...                                   ...    ...
# 5258   tm1120902                         The Privilege  MOVIE
# 5259    tm949382                          Looop Lapeta  MOVIE
# 5260   tm1144897                    My Father's Violin  MOVIE
# 5261    ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 5262   tm1137862                        Four to Dinner  MOVIE
#
#                                              description  release_year  \
# index
# 0      Dramatic rendition of a real life crime wave t...          1953
# ...

# %%
movies = movies.reset_index(drop=True)

# %%
movies
# Out:
#       index         id                                 title   type  \
# 0         0   tm102287                       Raya and Sakina  MOVIE
# 1         1    tm19608                       The Blazing Sun  MOVIE
# 2         2    tm16479                       White Christmas  MOVIE
# 3         3   tm204541                           Dark Waters  MOVIE
# 4         4   tm135083                         Cairo Station  MOVIE
# ...     ...        ...                                   ...    ...
# 5258   5258  tm1120902                         The Privilege  MOVIE
# 5259   5259   tm949382                          Looop Lapeta  MOVIE
# 5260   5260  tm1144897                    My Father's Violin  MOVIE
# 5261   5261   ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 5262   5262  tm1137862                        Four to Dinner  MOVIE
#
#                                             description  release_year  \
# 0     Dramatic rendition of a real life crime wave t...          1953
# ...

# %%
plt.figure(figsize=(10, 5))
plt.scatter(movies['runtime'], movies['imdb_score'])

# Adding title and labels
plt.title('Run Time vs IMDb Score')
plt.xlabel('Run Time (minutes)')
plt.ylabel('IMDb Score')
# Out:
# Text(0, 0.5, 'IMDb Score')

# %%
plt.figure(figsize=(10, 6))
plt.hist2d(movies['runtime'], movies['imdb_score'], bins=(20, 20), cmap='YlGnBu')


plt.colorbar(label='Count')
plt.title('2D Histogram: Run Time vs IMDb Score')
plt.xlabel('Run Time (minutes)')
plt.ylabel('IMDb Score')
plt.show()

# %%
movies.drop(columns='age_certification', inplace=True)

# %%
movies
# Out:
#       index         id                                 title   type  \
# 0         0   tm102287                       Raya and Sakina  MOVIE
# 1         1    tm19608                       The Blazing Sun  MOVIE
# 2         2    tm16479                       White Christmas  MOVIE
# 3         3   tm204541                           Dark Waters  MOVIE
# 4         4   tm135083                         Cairo Station  MOVIE
# ...     ...        ...                                   ...    ...
# 5258   5258  tm1120902                         The Privilege  MOVIE
# 5259   5259   tm949382                          Looop Lapeta  MOVIE
# 5260   5260  tm1144897                    My Father's Violin  MOVIE
# 5261   5261   ts343427  Samurai Rabbit: The Usagi Chronicles   SHOW
# 5262   5262  tm1137862                        Four to Dinner  MOVIE
#
#                                             description  release_year  \
# 0     Dramatic rendition of a real life crime wave t...          1953
# ...

# %%
df_sorted = movies.sort_values(by='imdb_score', ascending=False)

# %%
df_sorted
# Out:
#       index        id                              title   type  \
# 357     357  ts160526                           Khawatir   SHOW
# 2541   2541  ts265844                           #ABtalks   SHOW
# 479     479       ts4                       Breaking Bad   SHOW
# 341     341    ts3371         Avatar: The Last Airbender   SHOW
# 3143   3143   ts90621                       Kota Factory   SHOW
# ...     ...       ...                                ...    ...
# 4342   4342  tm839411   Me Against You: Mr. S's Vendetta  MOVIE
# 904     904  tm171891                         Himmatwala  MOVIE
# 5052   5052  ts280693  Thomas & Friends: All Engines Go!   SHOW
# 5203   5203  ts319303                     He's Expecting   SHOW
# 1425   1425  tm549892                            Aerials  MOVIE
#
#                                             description  release_year  \
# 357   A TV show devoted to help young people to be m...          2005
# ...

# %%
df_movies = df_sorted[df_sorted['type'] == 'MOVIE']
df_shows = df_sorted[df_sorted['type'] == 'SHOW']

# Concatenate movies and shows DataFrames
df_combined = pd.concat([df_movies, df_shows])

# Set 'Types' as the index
df_combined.set_index('type', inplace=True)

# Reset the index name if needed
df_combined.index.name = None

# %%
df_combined
# Out:
#        index        id                                     title  \
# MOVIE     31   tm76557                            No Longer Kids
# MOVIE   3771  tm853783  David Attenborough: A Life on Our Planet
# MOVIE    702  tm166740      Chhota Bheem & Krishna in Mayanagari
# MOVIE   2359  tm432327                         C/o Kancharapalem
# MOVIE   3759  tm907872                       Sky Tour: The Movie
# ...      ...       ...                                       ...
# SHOW    1932   ts81632                         A House of Blocks
# SHOW    5189  ts287149                                Hype House
# SHOW    4451  ts287941                               Racket Boys
# SHOW    5052  ts280693         Thomas & Friends: All Engines Go!
# SHOW    5203  ts319303                            He's Expecting
#
#                                              description  release_year  \
# MOVIE  By coincidence, Ahmad discovers that his fathe...          1979
# ...

# %%
df_movies.head(10)
# Out:
#       index        id                                     title   type  \
# 31       31   tm76557                            No Longer Kids  MOVIE
# 3771   3771  tm853783  David Attenborough: A Life on Our Planet  MOVIE
# 702     702  tm166740      Chhota Bheem & Krishna in Mayanagari  MOVIE
# 2359   2359  tm432327                         C/o Kancharapalem  MOVIE
# 3759   3759  tm907872                       Sky Tour: The Movie  MOVIE
# 620     620   tm92641                                 Inception  MOVIE
# 138     138  tm122434                              Forrest Gump  MOVIE
# 3079   3079  tm455981                             Rubaru Roshni  MOVIE
# 381     381   tm25842                       A Lion in the House  MOVIE
# 283     283  tm129763                                Anbe Sivam  MOVIE
#
#                                             description  release_year  \
# 31    By coincidence, Ahmad discovers that his fathe...          1979
# ...

# %%
df_shows.head(10)
# Out:
#       index        id                       title  type  \
# 357     357  ts160526                    Khawatir  SHOW
# 2541   2541  ts265844                    #ABtalks  SHOW
# 479     479       ts4                Breaking Bad  SHOW
# 341     341    ts3371  Avatar: The Last Airbender  SHOW
# 3143   3143   ts90621                Kota Factory  SHOW
# 3655   3655   ts85398                  Our Planet  SHOW
# 5163   5163  ts296563         Who Rules The World  SHOW
# 1151   1151   ts37660                  Reply 1988  SHOW
# 2962   2962   ts78298                   My Mister  SHOW
# 4914   4914  ts222333                      Arcane  SHOW
#
#                                             description  release_year  \
# 357   A TV show devoted to help young people to be m...          2005
# 2541  #ABtalks is a YouTube interview show hosted by...          2018
# 479   When Walter White, a New Mexico chemistry teac...          2008
# ...

# %%
df_shows_filtered = df_shows[df_shows['imdb_votes'] >= 5000]
# Out:
#       index        id                       title  type  \
# 479     479       ts4                Breaking Bad  SHOW
# 341     341    ts3371  Avatar: The Last Airbender  SHOW
# 3143   3143   ts90621                Kota Factory  SHOW
# 3655   3655   ts85398                  Our Planet  SHOW
# 1151   1151   ts37660                  Reply 1988  SHOW
# ...     ...       ...                         ...   ...
# 2397   2397   ts56480        Troy: Fall of a City  SHOW
# 109     109    ts8570            Barney & Friends  SHOW
# 3221   3221   ts90095                        Jinn  SHOW
# 2187   2187   ts55194    Bill Nye Saves the World  SHOW
# 4451   4451  ts287941                 Racket Boys  SHOW
#
#                                             description  release_year  \
# 479   When Walter White, a New Mexico chemistry teac...          2008
# 341   In a war-torn world of elemental magic, a youn...          2005
# 3143  Dedicated to Shrimati SL Loney ji, Shri Irodov...          2019
# ...

# %%
top10_shows = df_shows_filtered.head(10)

# %%
top10_shows
# Out:
#       index        id                       title  type  \
# 479     479       ts4                Breaking Bad  SHOW
# 341     341    ts3371  Avatar: The Last Airbender  SHOW
# 3143   3143   ts90621                Kota Factory  SHOW
# 3655   3655   ts85398                  Our Planet  SHOW
# 1151   1151   ts37660                  Reply 1988  SHOW
# 2962   2962   ts78298                   My Mister  SHOW
# 4914   4914  ts222333                      Arcane  SHOW
# 3887   3887   ts81120              The Last Dance  SHOW
# 732     732   ts32835             Hunter x Hunter  SHOW
# 989     989   ts20682             Attack on Titan  SHOW
#
#                                             description  release_year  \
# 479   When Walter White, a New Mexico chemistry teac...          2008
# 341   In a war-torn world of elemental magic, a youn...          2005
# 3143  Dedicated to Shrimati SL Loney ji, Shri Irodov...          2019
# ...

# %%
movies_df = df_movies[df_movies['imdb_votes'] == df_movies['imdb_votes'].max()]

# %%
movies_df
# Out:
#      index       id      title   type  \
# 620    620  tm92641  Inception  MOVIE
#
#                                            description  release_year  runtime  \
# 620  Cobb, a skilled thief who commits corporate es...          2010      148
#
#        imdb_id  imdb_score  imdb_votes
# 620  tt1375666         8.8   2268288.0

# %%
shows_df = df_shows[df_shows['imdb_votes'] == df_shows['imdb_votes'].max()]

# %%
shows_df
# Out:
#      index   id         title  type  \
# 479    479  ts4  Breaking Bad  SHOW
#
#                                            description  release_year  runtime  \
# 479  When Walter White, a New Mexico chemistry teac...          2008       48
#
#        imdb_id  imdb_score  imdb_votes
# 479  tt0903747         9.5   1727694.0
